# %%
import attiicc as ac
from attiicc.segmentation.sam import SamSegmenter
import os

# %%
image_path = "/media/ss4tbSSD/EDYER/nanowell_processing/images/p00_0_A01f00d0_2.png"
segment_img_save = "/media/ss4tbSSD/EDYER/nanowell_processing/sam_test_seg.png"
masks_img_save = "/media/ss4tbSSD/EDYER/nanowell_processing/sam_test_masks.png"
roi_path = "/home/ecdyer/labshare/LL07132018/NanoTry20231211/20X_H2O2_3_hours/ROIS"
model_path = "/media/ss4tbSSD/EDYER/nanowell_processing/weights/sam_vit_h_4b8939.pth"

# %%
test_sam = SamSegmenter(model_path=model_path, image_path=image_path)
# Out:
# CUDA is available.
# Number of CUDA devices: 1
# Model Loaded

# %%
test_sam.plot_segmented_image(save=True, save_path=segment_img_save)
test_sam.plot_masks(save=True, save_path=masks_img_save)

# %%
test_sam.generate_rois(save_path=roi_path)
# Out:
# Duplicate Value 1: (205, 905) Duplicate Value 2: (205, 905)
# Duplicate Value 1: (493, 427) Duplicate Value 2: (494, 427)
# Duplicate Value 1: (570, 65) Duplicate Value 2: (571, 66)
# Duplicate Value 1: (850, 69) Duplicate Value 2: (851, 69)
# Total number of ROIs:  71
# Saving ROIs to:  /home/ecdyer/labshare/LL07132018/NanoTry20231211/20X_H2O2_3_hours/ROIS/p00_0_A01f00d0_2
# Making directory at:  /home/ecdyer/labshare/LL07132018/NanoTry20231211/20X_H2O2_3_hours/ROIS/p00_0_A01f00d0_2
# Saving ROI:  p00_0_A01f00d0_2_ROI_1.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_2.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_3.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_4.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_5.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_6.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_7.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_8.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_9.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_10.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_11.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_12.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_13.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_14.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_15.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_16.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_17.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_18.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_19.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_20.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_21.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_22.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_23.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_24.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_25.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_26.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_27.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_28.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_29.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_30.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_31.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_32.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_33.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_34.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_35.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_36.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_37.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_38.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_39.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_40.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_41.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_42.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_43.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_44.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_45.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_46.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_47.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_48.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_49.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_50.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_51.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_52.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_53.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_54.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_55.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_56.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_57.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_58.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_59.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_60.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_61.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_62.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_63.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_64.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_65.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_66.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_67.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_68.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_69.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_70.roi
# Saving ROI:  p00_0_A01f00d0_2_ROI_71.roi
# {'p00_0_A01f00d0_2': [ImagejRoi(
#       roitype=ROI_TYPE.FREEHAND,
#       options=ROI_OPTIONS.OVERLAY_BACKGROUNDS | ROI_OPTIONS.OVERLAY_LABELS,
#       name='a8657c09-acb4-11ee-be85-490a135c3209',
#       version=226,
#       left=89,
#       bottom=123,
#       right=213,
#       n_coordinates=160,
#       integer_coordinates=numpy.array([
#           [ 55,   0],
#           [ 55,   1],
#           [ 54,   2],
#           [ 43,   2],
#           [ 42,   3],
#           [ 38,   3],
#           [ 37,   4],
#           [ 34,   4],
#           [ 33,   5],
#           [ 31,   5],
#           [ 30,   6],
#           [ 28,   6],
#           [ 27,   7],
#           [ 26,   7],
#           [ 25,   8],
#           [ 24,   8],
#           [ 22,  10],
#           [ 21,  10],
#           [ 20,  11],
#           [ 19,  11],
#           [ 18,  12],
#           [ 17,  12],
#           [ 12,  17],
#           [ 11,  17],
#           [ 10,  18],
#           [ 10,  19],
#           [  7,  22],
#           [  7,  23],
#           [  6,  24],
#           [  6,  25],
#           [  5,  26],
#           [  5,  27],
#           [  4,  28],
#           [  4,  30],
#           [  3,  31],
#           [  3,  34],
#           [  2,  35],
#           [  2,  40],
#           [  1,  41],
#           [  1,  56],
#           [  0,  57],
#           [  0,  60],
#           [  1,  61],
#           [  1,  75],
#           [  2,  76],
#           [  2,  82],
#           [  3,  83],
#           [  3,  85],
#           [  4,  86],
#           [  4,  88],
#           [  5,  89],
#           [  5,  91],
#           [  7,  93],
#           [  7,  94],
#           [  9,  96],
#           [ 10,  96],
#           [ 15, 101],
#           [ 16, 101],
#           [ 18, 103],
#           [ 19, 103],
#           [ 20, 104],
#           [ 21, 104],
#           [ 23, 106],
#           [ 25, 106],
#           [ 26, 107],
#           [ 27, 107],
#           [ 28, 108],
#           [ 30, 108],
#           [ 31, 109],
#           [ 33, 109],
#           [ 34, 110],
#           [ 35, 110],
#           [ 36, 111],
#           [ 37, 111],
#           [ 38, 112],
#           [ 39, 112],
#           [ 40, 113],
#           [ 41, 113],
#           [ 42, 114],
#           [ 43, 114],
#           [ 45, 116],
#           [ 46, 116],
#           [ 48, 118],
#           [ 49, 118],
#           [ 50, 119],
#           [ 51, 119],
#           [ 52, 120],
#           [ 53, 120],
#           [ 54, 121],
#           [ 62, 121],
#           [ 63, 122],
#           [ 64, 121],
#           [ 67, 121],
#           [ 68, 120],
#           [ 70, 120],
#           [ 71, 119],
#           [ 72, 119],
#           [ 73, 118],
#           [ 74, 118],
#           [ 75, 117],
#           [ 78, 117],
#           [ 79, 116],
#           [ 80, 116],
#           [ 81, 115],
#           [ 82, 115],
#           [ 84, 113],
#           [ 85, 113],
#           [ 88, 110],
#           [ 89, 110],
#           [ 92, 107],
#           [ 93, 107],
#           [ 95, 105],
#           [ 99, 105],
#           [103, 101],
#           [104, 101],
#           [107,  98],
#           [108,  98],
#           [112,  94],
#           [113,  94],
#           [113,  93],
#           [118,  88],
#           [118,  87],
#           [119,  86],
#           [119,  84],
#           [120,  83],
#           [120,  73],
#           [121,  72],
#           [121,  57],
#           [122,  56],
#           [122,  50],
#           [123,  49],
#           [123,  33],
#           [122,  32],
#           [122,  30],
#           [121,  29],
#           [121,  27],
#           [118,  24],
#           [118,  23],
#           [115,  20],
#           [115,  19],
#           [113,  17],
#           [112,  17],
#           [110,  15],
#           [109,  15],
#           [104,  10],
#           [103,  10],
#           [100,   7],
#           [ 99,   7],
#           [ 98,   6],
#           [ 97,   6],
#           [ 96,   5],
#           [ 95,   5],
#           [ 94,   4],
#           [ 90,   4],
#           [ 89,   3],
#           [ 84,   3],
#           [ 83,   2],
#           [ 75,   2],
#           [ 74,   1],
#           [ 74,   0]], dtype=int32),
#   ),
#   ImagejRoi(
#       roitype=ROI_TYPE.FREEHAND,
#       options=ROI_OPTIONS.OVERLAY_BACKGROUNDS | ROI_OPTIONS.OVERLAY_LABELS,
#       name='a8657c1e-acb4-11ee-be85-490a135c3209',
#       version=226,
#       left=229,
#       bottom=128,
#       right=355,
#       n_coordinates=173,
#       integer_coordinates=numpy.array([
#           [ 68,   0],
#           [ 68,   1],
#           [ 67,   2],
#           [ 56,   2],
#           [ 55,   3],
#           [ 50,   3],
#           [ 49,   2],
#           [ 48,   3],
#           [ 43,   3],
#           [ 42,   4],
#           [ 38,   4],
#           [ 37,   5],
#           [ 35,   5],
#           [ 34,   6],
#           [ 33,   6],
#           [ 32,   7],
#           [ 31,   7],
#           [ 29,   9],
#           [ 28,   9],
#           [ 27,  10],
#           [ 26,  10],
#           [ 25,  11],
#           [ 24,  11],
#           [ 22,  13],
#           [ 21,  13],
#           [ 20,  14],
#           [ 19,  14],
#           [ 18,  15],
#           [ 17,  15],
#           [ 15,  17],
#           [ 14,  17],
#           [  9,  22],
#           [  9,  23],
#           [  7,  25],
#           [  7,  26],
#           [  6,  27],
#           [  6,  28],
#           [  5,  29],
#           [  5,  30],
#           [  4,  31],
#           [  4,  32],
#           [  3,  33],
#           [  3,  36],
#           [  2,  37],
#           [  2,  41],
#           [  1,  42],
#           [  1,  55],
#           [  0,  56],
#           [  0,  73],
#           [  1,  74],
#           [  1,  82],
#           [  2,  83],
#           [  2, 101],
#           [  5, 104],
#           [  5, 105],
#           [ 12, 112],
#           [ 14, 112],
#           [ 15, 113],
#           [ 18, 113],
#           [ 19, 114],
#           [ 21, 114],
#           [ 22, 115],
#           [ 26, 115],
#           [ 27, 116],
#           [ 30, 116],
#           [ 31, 117],
#           [ 36, 117],
#           [ 37, 118],
#           [ 39, 118],
#           [ 40, 119],
#           [ 42, 119],
#           [ 43, 120],
#           [ 45, 120],
#           [ 46, 121],
#           [ 47, 121],
#           [ 48, 122],
#           [ 50, 122],
#           [ 51, 123],
#           [ 52, 123],
#           [ 53, 124],
#           [ 54, 124],
#           [ 55, 125],
#           [ 56, 125],
#           [ 57, 126],
#           [ 61, 126],
#           [ 62, 127],
#           [ 64, 127],
#           [ 65, 126],
#           [ 69, 126],
#           [ 72, 123],
#           [ 73, 123],
#           [ 75, 121],
#           [ 76, 121],
#           [ 78, 119],
#           [ 79, 119],
#           [ 80, 118],
#           [ 82, 118],
#           [ 83, 117],
#           [ 85, 117],
#           [ 86, 116],
#           [ 87, 116],
#           [ 89, 114],
#           [ 90, 114],
#           [ 92, 112],
#           [ 94, 112],
#           [ 96, 110],
#           [ 97, 110],
#           [ 99, 108],
#           [101, 108],
#           [102, 107],
#           [103, 107],
#           [104, 106],
#           [105, 106],
#           [107, 104],
#           [108, 104],
#           [110, 102],
#           [111, 102],
#           [116,  97],
#           [116,  96],
#           [118,  94],
#           [118,  93],
#           [119,  92],
#           [119,  91],
#           [120,  90],
#           [120,  88],
#           [121,  87],
#           [121,  84],
#           [122,  83],
#           [122,  79],
#           [123,  78],
#           [123,  73],
#           [124,  72],
#           [124,  48],
#           [125,  47],
#           [125,  39],
#           [124,  38],
#           [124,  34],
#           [123,  33],
#           [123,  32],
#           [122,  31],
#           [122,  30],
#           [121,  29],
#           [121,  28],
#           [120,  27],
#           [120,  26],
#           [118,  24],
#           [118,  23],
#           [112,  17],
#           [111,  17],
#           [109,  15],
#           [108,  15],
#           [106,  13],
#           [105,  13],
#           [104,  12],
#           [103,  12],
#           [102,  11],
#           [101,  11],
#           [100,  10],
#           [ 99,  10],
#           [ 98,   9],
#           [ 97,   9],
#           [ 95,   7],
#           [ 94,   7],
#           [ 92,   5],
#           [ 91,   5],
#           [ 90,   4],
#           [ 87,   4],
#           [ 86,   3],
#           [ 81,   3],
#           [ 80,   2],
#           [ 71,   2],
#           [ 70,   1],
#           [ 70,   0]], dtype=int32),
#   ),
#   ImagejRoi(
#       roitype=ROI_TYPE.FREEHAND,
#       options=ROI_OPTIONS.OVERLAY_BACKGROUNDS | ROI_OPTIONS.OVERLAY_LABELS,
#       name='a8657c06-acb4-11ee-be85-490a135c3209',
#       version=226,
#       top=3,
#       left=372,
#       bottom=129,
#       right=495,
#       n_coordinates=178,
#       integer_coordinates=numpy.array([
#           [ 46,   0],
#           [ 45,   1],
#           [ 42,   1],
#           [ 41,   2],
#           [ 39,   2],
#           [ 38,   3],
#           [ 37,   3],
#           [ 36,   4],
#           [ 35,   4],
#           [ 34,   5],
#           [ 33,   5],
#           [ 32,   6],
#           [ 31,   6],
#           [ 30,   7],
#           [ 29,   7],
#           [ 28,   8],
#           [ 27,   8],
#           [ 26,   9],
#           [ 25,   9],
#           [ 23,  11],
#           [ 22,  11],
#           [ 21,  12],
#           [ 20,  12],
#           [ 18,  14],
#           [ 17,  14],
#           [ 16,  15],
#           [ 15,  15],
#           [ 12,  18],
#           [ 11,  18],
#           [  9,  20],
#           [  9,  21],
#           [  5,  25],
#           [  5,  26],
#           [  4,  27],
#           [  4,  28],
#           [  3,  29],
#           [  3,  31],
#           [  2,  32],
#           [  2,  34],
#           [  1,  35],
#           [  1,  41],
#           [  0,  42],
#           [  0,  78],
#           [  1,  79],
#           [  1,  88],
#           [  2,  89],
#           [  2,  91],
#           [  3,  92],
#           [  3,  93],
#           [  6,  96],
#           [  6,  97],
#           [  8,  99],
#           [  9,  99],
#           [ 13, 103],
#           [ 14, 103],
#           [ 15, 104],
#           [ 16, 104],
#           [ 17, 105],
#           [ 18, 105],
#           [ 19, 106],
#           [ 20, 106],
#           [ 21, 107],
#           [ 22, 107],
#           [ 23, 108],
#           [ 24, 108],
#           [ 25, 109],
#           [ 26, 109],
#           [ 28, 111],
#           [ 29, 111],
#           [ 30, 112],
#           [ 31, 112],
#           [ 33, 114],
#           [ 34, 114],
#           [ 35, 115],
#           [ 36, 115],
#           [ 37, 116],
#           [ 38, 116],
#           [ 39, 117],
#           [ 40, 117],
#           [ 41, 118],
#           [ 42, 118],
#           [ 44, 120],
#           [ 45, 120],
#           [ 46, 121],
#           [ 47, 121],
#           [ 48, 122],
#           [ 49, 122],
#           [ 50, 123],
#           [ 51, 123],
#           [ 52, 124],
#           [ 53, 124],
#           [ 54, 125],
#           [ 66, 125],
#           [ 67, 124],
#           [ 69, 124],
#           [ 70, 123],
#           [ 72, 123],
#           [ 73, 122],
#           [ 74, 122],
#           [ 77, 119],
#           [ 78, 119],
#           [ 80, 117],
#           [ 81, 117],
#           [ 82, 116],
#           [ 83, 116],
#           [ 84, 115],
#           [ 86, 115],
#           [ 87, 114],
#           [ 88, 114],
#           [ 89, 113],
#           [ 90, 113],
#           [ 92, 111],
#           [ 93, 111],
#           [ 94, 110],
#           [ 95, 110],
#           [ 97, 108],
#           [ 98, 108],
#           [100, 106],
#           [101, 106],
#           [102, 105],
#           [103, 105],
#           [104, 104],
#           [105, 104],
#           [106, 103],
#           [107, 103],
#           [109, 101],
#           [110, 101],
#           [114,  97],
#           [114,  96],
#           [115,  95],
#           [115,  94],
#           [116,  93],
#           [116,  92],
#           [117,  91],
#           [117,  90],
#           [118,  89],
#           [118,  87],
#           [119,  86],
#           [119,  82],
#           [120,  81],
#           [120,  75],
#           [121,  74],
#           [121,  62],
#           [122,  61],
#           [122,  45],
#           [121,  44],
#           [121,  38],
#           [120,  37],
#           [120,  35],
#           [119,  34],
#           [119,  32],
#           [118,  31],
#           [118,  30],
#           [117,  29],
#           [117,  28],
#           [114,  25],
#           [114,  24],
#           [106,  16],
#           [105,  16],
#           [103,  14],
#           [102,  14],
#           [100,  12],
#           [ 99,  12],
#           [ 98,  11],
#           [ 97,  11],
#           [ 94,   8],
#           [ 93,   8],
#           [ 92,   7],
#           [ 90,   7],
#           [ 89,   6],
#           [ 88,   6],
#           [ 85,   3],
#           [ 84,   3],
#           [ 83,   2],
#           [ 82,   2],
#           [ 81,   1],
#           [ 77,   1],
#           [ 76,   0]], dtype=int32),
#   ),
#   ImagejRoi(
#       roitype=ROI_TYPE.FREEHAND,
#       options=ROI_OPTIONS.OVERLAY_BACKGROUNDS | ROI_OPTIONS.OVERLAY_LABELS,
#       name='a8657c20-acb4-11ee-be85-490a135c3209',
#       version=226,
#       top=3,
#       left=510,
#       bottom=135,
#       right=635,
#       n_coordinates=176,
#       integer_coordinates=numpy.array([
#           [ 54,   0],
#           [ 53,   1],
#           [ 47,   1],
#           [ 46,   2],
#           [ 44,   2],
#           [ 43,   3],
#           [ 41,   3],
#           [ 40,   4],
#           [ 39,   4],
#           [ 38,   5],
#           [ 37,   5],
#           [ 36,   6],
#           [ 35,   6],
#           [ 34,   7],
#           [ 33,   7],
#           [ 32,   8],
#           [ 31,   8],
#           [ 30,   9],
#           [ 29,   9],
#           [ 28,  10],
#           [ 26,  10],
#           [ 24,  12],
#           [ 23,  12],
#           [ 22,  13],
#           [ 21,  13],
#           [ 19,  15],
#           [ 18,  15],
#           [ 11,  22],
#           [ 10,  22],
#           [ 10,  23],
#           [  6,  27],
#           [  6,  28],
#           [  4,  30],
#           [  4,  32],
#           [  3,  33],
#           [  3,  35],
#           [  2,  36],
#           [  2,  40],
#           [  1,  41],
#           [  1,  48],
#           [  0,  49],
#           [  0,  80],
#           [  1,  81],
#           [  1,  86],
#           [  2,  87],
#           [  2,  90],
#           [  3,  91],
#           [  3,  93],
#           [  4,  94],
#           [  4,  96],
#           [  5,  97],
#           [  5,  98],
#           [  7, 100],
#           [  7, 101],
#           [ 12, 106],
#           [ 13, 106],
#           [ 16, 109],
#           [ 17, 109],
#           [ 18, 110],
#           [ 19, 110],
#           [ 22, 113],
#           [ 23, 113],
#           [ 24, 114],
#           [ 25, 114],
#           [ 26, 115],
#           [ 27, 115],
#           [ 29, 117],
#           [ 30, 117],
#           [ 32, 119],
#           [ 33, 119],
#           [ 34, 120],
#           [ 35, 120],
#           [ 44, 129],
#           [ 46, 129],
#           [ 47, 130],
#           [ 51, 130],
#           [ 52, 131],
#           [ 61, 131],
#           [ 62, 130],
#           [ 64, 130],
#           [ 65, 129],
#           [ 67, 129],
#           [ 68, 128],
#           [ 69, 128],
#           [ 70, 127],
#           [ 72, 127],
#           [ 73, 126],
#           [ 74, 126],
#           [ 75, 125],
#           [ 76, 125],
#           [ 77, 124],
#           [ 78, 124],
#           [ 79, 123],
#           [ 80, 123],
#           [ 82, 121],
#           [ 83, 121],
#           [ 83, 120],
#           [ 85, 118],
#           [ 86, 118],
#           [ 88, 116],
#           [ 90, 116],
#           [ 91, 115],
#           [ 93, 115],
#           [ 94, 114],
#           [ 95, 114],
#           [ 96, 113],
#           [ 97, 113],
#           [ 98, 112],
#           [ 99, 112],
#           [100, 111],
#           [101, 111],
#           [103, 109],
#           [104, 109],
#           [106, 107],
#           [107, 107],
#           [111, 103],
#           [112, 103],
#           [114, 101],
#           [114, 100],
#           [116,  98],
#           [116,  97],
#           [117,  96],
#           [117,  95],
#           [118,  94],
#           [118,  93],
#           [119,  92],
#           [119,  91],
#           [120,  90],
#           [120,  88],
#           [121,  87],
#           [121,  83],
#           [122,  82],
#           [122,  77],
#           [123,  76],
#           [123,  68],
#           [124,  67],
#           [124,  52],
#           [123,  51],
#           [123,  41],
#           [122,  40],
#           [122,  38],
#           [121,  37],
#           [121,  36],
#           [120,  35],
#           [120,  33],
#           [119,  32],
#           [119,  31],
#           [117,  29],
#           [117,  28],
#           [107,  18],
#           [106,  18],
#           [104,  16],
#           [103,  16],
#           [101,  14],
#           [100,  14],
#           [ 98,  12],
#           [ 97,  12],
#           [ 96,  11],
#           [ 95,  11],
#           [ 93,   9],
#           [ 92,   9],
#           [ 91,   8],
#           [ 90,   8],
#           [ 89,   7],
#           [ 88,   7],
#           [ 87,   6],
#           [ 86,   6],
#           [ 85,   5],
#           [ 84,   5],
#           [ 82,   3],
#           [ 81,   3],
#           [ 80,   2],
#           [ 78,   2],
#           [ 77,   1],
#           [ 71,   1],
#           [ 70,   0]], dtype=int32),
#   ),
#   ImagejRoi(
#       roitype=ROI_TYPE.FREEHAND,
#       options=ROI_OPTIONS.OVERLAY_BACKGROUNDS | ROI_OPTIONS.OVERLAY_LABELS,
#       name='a8657bf5-acb4-11ee-be85-490a135c3209',
#       version=226,
#       top=4,
#       left=650,
#       bottom=128,
#       right=774,
#       n_coordinates=170,
#       integer_coordinates=numpy.array([
#           [ 55,   0],
#           [ 54,   1],
#           [ 50,   1],
#           [ 49,   2],
#           [ 47,   2],
#           [ 45,   4],
#           [ 44,   4],
#           [ 43,   5],
#           [ 42,   5],
#           [ 41,   6],
#           [ 40,   6],
#           [ 39,   7],
#           [ 38,   7],
#           [ 36,   9],
#           [ 35,   9],
#           [ 34,  10],
#           [ 33,  10],
#           [ 31,  12],
#           [ 30,  12],
#           [ 29,  13],
#           [ 28,  13],
#           [ 27,  14],
#           [ 26,  14],
#           [ 24,  16],
#           [ 23,  16],
#           [ 21,  18],
#           [ 20,  18],
#           [ 19,  19],
#           [ 18,  19],
#           [ 14,  23],
#           [ 13,  23],
#           [  6,  30],
#           [  6,  31],
#           [  5,  32],
#           [  5,  33],
#           [  4,  34],
#           [  4,  35],
#           [  3,  36],
#           [  3,  37],
#           [  2,  38],
#           [  2,  41],
#           [  1,  42],
#           [  1,  47],
#           [  0,  48],
#           [  0,  73],
#           [  1,  74],
#           [  1,  79],
#           [  2,  80],
#           [  2,  84],
#           [  3,  85],
#           [  3,  88],
#           [  4,  89],
#           [  4,  91],
#           [  6,  93],
#           [  6,  94],
#           [  9,  97],
#           [  9,  98],
#           [ 15, 104],
#           [ 16, 104],
#           [ 19, 107],
#           [ 20, 107],
#           [ 21, 108],
#           [ 22, 108],
#           [ 23, 109],
#           [ 24, 109],
#           [ 26, 111],
#           [ 27, 111],
#           [ 28, 112],
#           [ 29, 112],
#           [ 30, 113],
#           [ 32, 113],
#           [ 33, 114],
#           [ 34, 114],
#           [ 35, 115],
#           [ 36, 115],
#           [ 37, 116],
#           [ 39, 116],
#           [ 40, 117],
#           [ 41, 117],
#           [ 42, 118],
#           [ 43, 118],
#           [ 45, 120],
#           [ 46, 120],
#           [ 48, 122],
#           [ 50, 122],
#           [ 51, 123],
#           [ 68, 123],
#           [ 69, 122],
#           [ 71, 122],
#           [ 72, 121],
#           [ 74, 121],
#           [ 75, 120],
#           [ 77, 120],
#           [ 78, 119],
#           [ 79, 119],
#           [ 80, 118],
#           [ 82, 118],
#           [ 83, 117],
#           [ 84, 117],
#           [ 85, 116],
#           [ 87, 116],
#           [ 88, 115],
#           [ 89, 115],
#           [ 90, 114],
#           [ 91, 114],
#           [ 92, 113],
#           [ 94, 113],
#           [ 95, 112],
#           [ 97, 112],
#           [ 98, 111],
#           [ 99, 111],
#           [100, 110],
#           [101, 110],
#           [102, 109],
#           [104, 109],
#           [106, 107],
#           [107, 107],
#           [109, 105],
#           [110, 105],
#           [115, 100],
#           [115,  99],
#           [117,  97],
#           [117,  96],
#           [119,  94],
#           [119,  93],
#           [120,  92],
#           [120,  90],
#           [121,  89],
#           [121,  87],
#           [122,  86],
#           [122,  71],
#           [123,  70],
#           [123,  47],
#           [122,  46],
#           [122,  42],
#           [121,  41],
#           [121,  38],
#           [120,  37],
#           [120,  36],
#           [119,  35],
#           [119,  34],
#           [117,  32],
#           [117,  31],
#           [111,  25],
#           [110,  25],
#           [103,  18],
#           [102,  18],
#           [ 99,  15],
#           [ 98,  15],
#           [ 96,  13],
#           [ 95,  13],
#           [ 94,  12],
#           [ 93,  12],
#           [ 92,  11],
#           [ 91,  11],
#           [ 90,  10],
#           [ 89,  10],
#           [ 88,   9],
#           [ 87,   9],
#           [ 85,   7],
#           [ 84,   7],
#           [ 83,   6],
#           [ 81,   6],
#           [ 80,   5],
#           [ 78,   5],
#           [ 76,   3],
#           [ 75,   3],
#           [ 73,   1],
#           [ 71,   1],
#           [ 70,   0]], dtype=int32),
#   ),
#   ImagejRoi(
#       roitype=ROI_TYPE.FREEHAND,
#       options=ROI_OPTIONS.OVERLAY_BACKGROUNDS | ROI_OPTIONS.OVERLAY_LABELS,
#       name='a8657be7-acb4-11ee-be85-490a135c3209',
#       version=226,
#       top=6,
#       left=789,
#       bottom=135,
#       right=914,
#       n_coordinates=206,
#       integer_coordinates=numpy.array([
#           [ 58,   0],
#           [ 57,   1],
#           [ 54,   1],
#           [ 53,   2],
#           [ 52,   2],
#           [ 51,   3],
#           [ 49,   3],
#           [ 48,   4],
#           [ 47,   4],
#           [ 46,   5],
#           [ 45,   5],
#           [ 44,   6],
#           [ 43,   6],
#           [ 42,   7],
#           [ 41,   7],
#           [ 40,   8],
#           [ 38,   8],
#           [ 37,   9],
#           [ 36,   9],
#           [ 35,  10],
#           [ 34,  10],
#           [ 33,  11],
#           [ 32,  11],
#           [ 31,  12],
#           [ 30,  12],
#           [ 28,  14],
#           [ 27,  14],
#           [ 26,  15],
#           [ 25,  15],
#           [ 23,  17],
#           [ 22,  17],
#           [ 19,  20],
#           [ 18,  20],
#           [ 15,  23],
#           [ 14,  23],
#           [ 12,  25],
#           [ 11,  25],
#           [  7,  29],
#           [  7,  30],
#           [  5,  32],
#           [  5,  33],
#           [  4,  34],
#           [  4,  35],
#           [  3,  36],
#           [  3,  38],
#           [  2,  39],
#           [  2,  42],
#           [  1,  43],
#           [  1,  50],
#           [  0,  51],
#           [  0,  74],
#           [  1,  75],
#           [  1,  82],
#           [  2,  83],
#           [  2,  87],
#           [  3,  88],
#           [  3,  91],
#           [  4,  92],
#           [  4,  94],
#           [  5,  95],
#           [  5,  96],
#           [  7,  98],
#           [  7,  99],
#           [ 11, 103],
#           [ 12, 103],
#           [ 16, 107],
#           [ 17, 107],
#           [ 18, 108],
#           [ 19, 108],
#           [ 21, 110],
#           [ 22, 110],
#           [ 23, 111],
#           [ 24, 111],
#           [ 26, 113],
#           [ 27, 113],
#           [ 29, 115],
#           [ 30, 115],
#           [ 32, 117],
#           [ 33, 117],
#           [ 35, 119],
#           [ 36, 119],
#           [ 37, 120],
#           [ 39, 120],
#           [ 40, 121],
#           [ 42, 121],
#           [ 43, 122],
#           [ 44, 122],
#           [ 46, 124],
#           [ 47, 124],
#           [ 48, 125],
#           [ 49, 125],
#           [ 50, 126],
#           [ 51, 126],
#           [ 52, 127],
#           [ 53, 127],
#           [ 54, 128],
#           [ 62, 128],
#           [ 63, 127],
#           [ 66, 127],
#           [ 67, 126],
#           [ 68, 126],
#           [ 69, 125],
#           [ 70, 125],
#           [ 71, 124],
#           [ 73, 124],
#           [ 74, 123],
#           [ 75, 123],
#           [ 76, 122],
#           [ 77, 122],
#           [ 78, 121],
#           [ 80, 121],
#           [ 81, 120],
#           [ 83, 120],
#           [ 84, 119],
#           [ 85, 119],
#           [ 86, 118],
#           [ 88, 118],
#           [ 89, 117],
#           [ 90, 117],
#           [ 91, 116],
#           [ 92, 116],
#           [ 93, 115],
#           [ 94, 115],
#           [ 95, 114],
#           [ 96, 114],
#           [ 97, 113],
#           [ 98, 113],
#           [ 99, 112],
#           [100, 112],
#           [101, 111],
#           [103, 111],
#           [104, 110],
#           [105, 110],
#           [106, 109],
#           [107, 109],
#           [108, 108],
#           [109, 108],
#           [110, 107],
#           [111, 107],
#           [115, 103],
#           [115, 102],
#           [117, 100],
#           [117,  99],
#           [118,  98],
#           [118,  97],
#           [119,  96],
#           [119,  94],
#           [120,  93],
#           [120,  91],
#           [121,  90],
#           [121,  87],
#           [122,  86],
#           [122,  78],
#           [123,  77],
#           [123,  66],
#           [124,  65],
#           [124,  46],
#           [123,  45],
#           [123,  41],
#           [122,  40],
#           [122,  38],
#           [121,  37],
#           [121,  36],
#           [120,  35],
#           [120,  34],
#           [119,  33],
#           [119,  32],
#           [117,  30],
#           [117,  29],
#           [115,  27],
#           [115,  26],
#           [111,  22],
#           [110,  22],
#           [108,  20],
#           [107,  20],
#           [104,  17],
#           [103,  17],
#           [102,  16],
#           [101,  16],
#           [100,  15],
#           [ 99,  15],
#           [ 98,  14],
#           [ 97,  14],
#           [ 95,  12],
#           [ 94,  12],
#           [ 93,  11],
#           [ 92,  11],
#           [ 90,   9],
#           [ 89,   9],
#           [ 88,   8],
#           [ 87,   8],
#           [ 86,   7],
#           [ 84,   7],
#           [ 83,   6],
#           [ 81,   6],
#           [ 80,   5],
#           [ 79,   5],
#           [ 78,   4],
#           [ 77,   4],
#           [ 76,   3],
#           [ 74,   3],
#           [ 73,   2],
#           [ 72,   2],
#           [ 71,   1],
#           [ 70,   1],
#           [ 69,   0]], dtype=int32),
#   ),
#   ImagejRoi(
#       roitype=ROI_TYPE.FREEHAND,
#       options=ROI_OPTIONS.OVERLAY_BACKGROUNDS | ROI_OPTIONS.OVERLAY_LABELS,
#       name='a8657c10-acb4-11ee-be85-490a135c3209',
#       version=226,
#       top=7,
#       left=931,
#       bottom=136,
#       right=1054,
#       n_coordinates=172,
#       integer_coordinates=numpy.array([
#           [ 56,   0],
#           [ 55,   1],
#           [ 54,   1],
#           [ 53,   2],
#           [ 49,   2],
#           [ 48,   3],
#           [ 46,   3],
#           [ 45,   4],
#           [ 44,   4],
#           [ 42,   6],
#           [ 41,   6],
#           [ 39,   8],
#           [ 38,   8],
#           [ 37,   9],
#           [ 35,   9],
#           [ 33,  11],
#           [ 32,  11],
#           [ 30,  13],
#           [ 28,  13],
#           [ 27,  14],
#           [ 26,  14],
#           [ 25,  15],
#           [ 24,  15],
#           [ 23,  16],
#           [ 22,  16],
#           [ 20,  18],
#           [ 19,  18],
#           [ 18,  19],
#           [ 17,  19],
#           [ 15,  21],
#           [ 14,  21],
#           [ 10,  25],
#           [  9,  25],
#           [  4,  30],
#           [  4,  31],
#           [  3,  32],
#           [  3,  33],
#           [  2,  34],
#           [  2,  35],
#           [  1,  36],
#           [  1,  39],
#           [  0,  40],
#           [  0,  65],
#           [  1,  66],
#           [  1,  86],
#           [  2,  87],
#           [  2,  94],
#           [  3,  95],
#           [  3,  96],
#           [  4,  97],
#           [  4,  98],
#           [  7, 101],
#           [  7, 102],
#           [ 14, 109],
#           [ 15, 109],
#           [ 16, 110],
#           [ 20, 110],
#           [ 21, 111],
#           [ 22, 111],
#           [ 23, 112],
#           [ 25, 112],
#           [ 26, 113],
#           [ 34, 113],
#           [ 35, 114],
#           [ 42, 114],
#           [ 43, 115],
#           [ 43, 116],
#           [ 45, 118],
#           [ 46, 118],
#           [ 47, 119],
#           [ 48, 119],
#           [ 49, 120],
#           [ 50, 120],
#           [ 51, 121],
#           [ 52, 121],
#           [ 55, 124],
#           [ 56, 124],
#           [ 57, 125],
#           [ 58, 125],
#           [ 59, 126],
#           [ 62, 126],
#           [ 63, 127],
#           [ 66, 127],
#           [ 67, 128],
#           [ 68, 128],
#           [ 69, 127],
#           [ 73, 127],
#           [ 74, 126],
#           [ 77, 126],
#           [ 78, 125],
#           [ 79, 125],
#           [ 80, 124],
#           [ 81, 124],
#           [ 82, 123],
#           [ 85, 123],
#           [ 86, 122],
#           [ 88, 122],
#           [ 89, 121],
#           [ 90, 121],
#           [ 91, 120],
#           [ 92, 120],
#           [ 93, 119],
#           [ 94, 119],
#           [ 98, 115],
#           [ 99, 115],
#           [100, 114],
#           [101, 114],
#           [103, 112],
#           [104, 112],
#           [106, 110],
#           [107, 110],
#           [110, 107],
#           [111, 107],
#           [115, 103],
#           [115, 102],
#           [116, 101],
#           [116,  99],
#           [117,  98],
#           [117,  97],
#           [119,  95],
#           [119,  94],
#           [120,  93],
#           [120,  86],
#           [121,  85],
#           [121,  64],
#           [122,  63],
#           [122,  60],
#           [121,  59],
#           [121,  45],
#           [120,  44],
#           [120,  40],
#           [119,  39],
#           [119,  37],
#           [118,  36],
#           [118,  35],
#           [116,  33],
#           [116,  32],
#           [113,  29],
#           [113,  28],
#           [112,  27],
#           [111,  27],
#           [107,  23],
#           [106,  23],
#           [103,  20],
#           [102,  20],
#           [100,  18],
#           [ 99,  18],
#           [ 97,  16],
#           [ 96,  16],
#           [ 94,  14],
#           [ 93,  14],
#           [ 92,  13],
#           [ 91,  13],
#           [ 89,  11],
#           [ 88,  11],
#           [ 87,  10],
#           [ 86,  10],
#           [ 85,   9],
#           [ 83,   9],
#           [ 82,   8],
#           [ 80,   8],
#           [ 78,   6],
#           [ 77,   6],
#           [ 75,   4],
#           [ 74,   4],
#           [ 73,   3],
#           [ 71,   3],
#           [ 70,   2],
#           [ 69,   2],
#           [ 68,   1],
#           [ 67,   1],
#           [ 66,   0]], dtype=int32),
#   ),
#   ImagejRoi(
#       roitype=ROI_TYPE.FREEHAND,
#       options=ROI_OPTIONS.OVERLAY_BACKGROUNDS | ROI_OPTIONS.OVERLAY_LABELS,
#       name='a8657c1a-acb4-11ee-be85-490a135c3209',
#       version=226,
#       top=10,
#       left=1072,
#       bottom=140,
#       right=1194,
#       n_coordinates=182,
#       integer_coordinates=numpy.array([
#           [ 56,   0],
#           [ 55,   1],
#           [ 52,   1],
#           [ 51,   2],
#           [ 49,   2],
#           [ 48,   3],
#           [ 46,   3],
#           [ 45,   4],
#           [ 44,   4],
#           [ 42,   6],
#           [ 41,   6],
#           [ 40,   7],
#           [ 39,   7],
#           [ 38,   8],
#           [ 37,   8],
#           [ 36,   9],
#           [ 35,   9],
#           [ 34,  10],
#           [ 33,  10],
#           [ 32,  11],
#           [ 31,  11],
#           [ 30,  12],
#           [ 29,  12],
#           [ 28,  13],
#           [ 27,  13],
#           [ 26,  14],
#           [ 25,  14],
#           [ 24,  15],
#           [ 23,  15],
#           [ 22,  16],
#           [ 21,  16],
#           [ 20,  17],
#           [ 19,  17],
#           [ 17,  19],
#           [ 16,  19],
#           [ 14,  21],
#           [ 13,  21],
#           [  7,  27],
#           [  7,  28],
#           [  4,  31],
#           [  4,  32],
#           [  3,  33],
#           [  3,  34],
#           [  2,  35],
#           [  2,  36],
#           [  1,  37],
#           [  1,  38],
#           [  0,  39],
#           [  0,  61],
#           [  1,  62],
#           [  1,  86],
#           [  2,  87],
#           [  2,  92],
#           [  3,  93],
#           [  3,  96],
#           [  5,  98],
#           [  5,  99],
#           [  9, 103],
#           [ 10, 103],
#           [ 13, 106],
#           [ 14, 106],
#           [ 16, 108],
#           [ 17, 108],
#           [ 18, 109],
#           [ 19, 109],
#           [ 20, 110],
#           [ 21, 110],
#           [ 24, 113],
#           [ 25, 113],
#           [ 26, 114],
#           [ 27, 114],
#           [ 28, 115],
#           [ 29, 115],
#           [ 30, 116],
#           [ 31, 116],
#           [ 34, 119],
#           [ 35, 119],
#           [ 37, 121],
#           [ 38, 121],
#           [ 39, 122],
#           [ 40, 122],
#           [ 42, 124],
#           [ 43, 124],
#           [ 45, 126],
#           [ 47, 126],
#           [ 48, 127],
#           [ 50, 127],
#           [ 51, 128],
#           [ 54, 128],
#           [ 55, 129],
#           [ 59, 129],
#           [ 60, 128],
#           [ 66, 128],
#           [ 67, 127],
#           [ 70, 127],
#           [ 71, 126],
#           [ 73, 126],
#           [ 74, 125],
#           [ 76, 125],
#           [ 77, 124],
#           [ 79, 124],
#           [ 80, 123],
#           [ 82, 123],
#           [ 83, 122],
#           [ 84, 122],
#           [ 85, 121],
#           [ 86, 121],
#           [ 87, 120],
#           [ 88, 120],
#           [ 89, 119],
#           [ 91, 119],
#           [ 92, 118],
#           [ 93, 118],
#           [ 95, 116],
#           [ 97, 116],
#           [ 99, 114],
#           [100, 114],
#           [101, 113],
#           [102, 113],
#           [105, 110],
#           [106, 110],
#           [114, 102],
#           [114, 101],
#           [115, 100],
#           [115,  99],
#           [116,  98],
#           [116,  97],
#           [117,  96],
#           [117,  93],
#           [118,  92],
#           [118,  90],
#           [119,  89],
#           [119,  86],
#           [120,  85],
#           [120,  80],
#           [121,  79],
#           [121,  51],
#           [120,  50],
#           [120,  42],
#           [119,  41],
#           [119,  39],
#           [118,  38],
#           [118,  36],
#           [117,  35],
#           [117,  34],
#           [116,  33],
#           [116,  32],
#           [114,  30],
#           [114,  29],
#           [111,  26],
#           [110,  26],
#           [107,  23],
#           [106,  23],
#           [105,  22],
#           [104,  22],
#           [103,  21],
#           [102,  21],
#           [101,  20],
#           [100,  20],
#           [ 99,  19],
#           [ 98,  19],
#           [ 96,  17],
#           [ 95,  17],
#           [ 93,  15],
#           [ 92,  15],
#           [ 89,  12],
#           [ 88,  12],
#           [ 87,  11],
#           [ 86,  11],
#           [ 85,  10],
#           [ 84,  10],
#           [ 82,   8],
#           [ 81,   8],
#           [ 78,   5],
#           [ 77,   5],
#           [ 75,   3],
#           [ 74,   3],
#           [ 73,   2],
#           [ 70,   2],
#           [ 69,   1],
#           [ 65,   1],
#           [ 64,   0]], dtype=int32),
#   ),
#   ImagejRoi(
#       roitype=ROI_TYPE.FREEHAND,
#       options=ROI_OPTIONS.OVERLAY_BACKGROUNDS | ROI_OPTIONS.OVERLAY_LABELS,
#       name='a8657c24-acb4-11ee-be85-490a135c3209',
#       version=226,
#       top=111,
#       left=16,
#       bottom=242,
#       right=142,
#       n_coordinates=184,
#       integer_coordinates=numpy.array([
#           [ 59,   0],
#           [ 58,   1],
#           [ 55,   1],
#           [ 54,   2],
#           [ 52,   2],
#           [ 51,   3],
#           [ 50,   3],
#           [ 49,   4],
#           [ 48,   4],
#           [ 47,   5],
#           [ 46,   5],
#           [ 44,   7],
#           [ 43,   7],
#           [ 42,   8],
#           [ 41,   8],
#           [ 40,   9],
#           [ 39,   9],
#           [ 38,  10],
#           [ 37,  10],
#           [ 35,  12],
#           [ 34,  12],
#           [ 33,  13],
#           [ 32,  13],
#           [ 31,  14],
#           [ 30,  14],
#           [ 29,  15],
#           [ 28,  15],
#           [ 27,  16],
#           [ 26,  16],
#           [ 25,  17],
#           [ 24,  17],
#           [ 23,  18],
#           [ 22,  18],
#           [ 21,  19],
#           [ 20,  19],
#           [ 18,  21],
#           [ 17,  21],
#           [ 16,  22],
#           [ 15,  22],
#           [  7,  30],
#           [  7,  31],
#           [  5,  33],
#           [  5,  34],
#           [  4,  35],
#           [  4,  36],
#           [  3,  37],
#           [  3,  41],
#           [  2,  42],
#           [  2,  52],
#           [  1,  53],
#           [  1,  67],
#           [  0,  68],
#           [  0,  84],
#           [  1,  85],
#           [  1,  93],
#           [  2,  94],
#           [  2,  96],
#           [  3,  97],
#           [  3,  98],
#           [  8, 103],
#           [  9, 103],
#           [ 13, 107],
#           [ 14, 107],
#           [ 17, 110],
#           [ 18, 110],
#           [ 20, 112],
#           [ 21, 112],
#           [ 22, 113],
#           [ 23, 113],
#           [ 26, 116],
#           [ 27, 116],
#           [ 28, 117],
#           [ 29, 117],
#           [ 31, 119],
#           [ 32, 119],
#           [ 33, 120],
#           [ 34, 120],
#           [ 36, 122],
#           [ 37, 122],
#           [ 38, 123],
#           [ 39, 123],
#           [ 40, 124],
#           [ 41, 124],
#           [ 42, 125],
#           [ 44, 125],
#           [ 45, 126],
#           [ 46, 126],
#           [ 47, 127],
#           [ 49, 127],
#           [ 50, 128],
#           [ 52, 128],
#           [ 53, 129],
#           [ 57, 129],
#           [ 58, 130],
#           [ 65, 130],
#           [ 66, 129],
#           [ 68, 129],
#           [ 69, 128],
#           [ 71, 128],
#           [ 72, 127],
#           [ 74, 127],
#           [ 76, 125],
#           [ 77, 125],
#           [ 78, 124],
#           [ 80, 124],
#           [ 81, 123],
#           [ 91, 123],
#           [ 92, 122],
#           [ 95, 122],
#           [ 96, 121],
#           [ 98, 121],
#           [ 99, 120],
#           [100, 120],
#           [102, 118],
#           [103, 118],
#           [110, 111],
#           [110, 110],
#           [114, 106],
#           [114, 105],
#           [117, 102],
#           [117, 101],
#           [119,  99],
#           [119,  98],
#           [120,  97],
#           [120,  92],
#           [121,  91],
#           [121,  87],
#           [122,  86],
#           [122,  83],
#           [123,  82],
#           [123,  72],
#           [124,  71],
#           [124,  59],
#           [125,  58],
#           [125,  57],
#           [124,  56],
#           [124,  44],
#           [123,  43],
#           [123,  38],
#           [122,  37],
#           [122,  36],
#           [121,  35],
#           [121,  34],
#           [120,  33],
#           [120,  32],
#           [119,  31],
#           [119,  29],
#           [118,  28],
#           [118,  27],
#           [113,  22],
#           [112,  22],
#           [109,  19],
#           [108,  19],
#           [106,  17],
#           [105,  17],
#           [104,  16],
#           [103,  16],
#           [102,  15],
#           [101,  15],
#           [ 99,  13],
#           [ 98,  13],
#           [ 97,  12],
#           [ 96,  12],
#           [ 95,  11],
#           [ 93,  11],
#           [ 92,  10],
#           [ 91,  10],
#           [ 89,   8],
#           [ 88,   8],
#           [ 87,   7],
#           [ 86,   7],
#           [ 85,   6],
#           [ 84,   6],
#           [ 83,   5],
#           [ 82,   5],
#           [ 81,   4],
#           [ 80,   4],
#           [ 79,   3],
#           [ 78,   3],
#           [ 77,   2],
#           [ 74,   2],
#           [ 73,   1],
#           [ 69,   1],
#           [ 68,   0]], dtype=int32),
#   ),
#   ImagejRoi(
#       roitype=ROI_TYPE.FREEHAND,
#       options=ROI_OPTIONS.OVERLAY_BACKGROUNDS | ROI_OPTIONS.OVERLAY_LABELS,
#       name='a8657c0d-acb4-11ee-be85-490a135c3209',
#       version=226,
#       top=115,
#       left=158,
#       bottom=246,
#       right=284,
#       n_coordinates=190,
#       integer_coordinates=numpy.array([
#           [ 56,   0],
#           [ 55,   1],
#           [ 53,   1],
#           [ 52,   2],
#           [ 51,   2],
#           [ 50,   3],
#           [ 48,   3],
#           [ 47,   4],
#           [ 46,   4],
#           [ 45,   5],
#           [ 44,   5],
#           [ 43,   6],
#           [ 41,   6],
#           [ 40,   7],
#           [ 39,   7],
#           [ 38,   8],
#           [ 37,   8],
#           [ 36,   9],
#           [ 35,   9],
#           [ 34,  10],
#           [ 33,  10],
#           [ 32,  11],
#           [ 31,  11],
#           [ 30,  12],
#           [ 29,  12],
#           [ 28,  13],
#           [ 27,  13],
#           [ 26,  14],
#           [ 25,  14],
#           [ 23,  16],
#           [ 22,  16],
#           [ 21,  17],
#           [ 20,  17],
#           [ 19,  18],
#           [ 18,  18],
#           [ 17,  19],
#           [ 16,  19],
#           [ 12,  23],
#           [ 11,  23],
#           [  5,  29],
#           [  5,  30],
#           [  4,  31],
#           [  4,  32],
#           [  3,  33],
#           [  3,  34],
#           [  2,  35],
#           [  2,  36],
#           [  1,  37],
#           [  1,  41],
#           [  0,  42],
#           [  0,  85],
#           [  1,  86],
#           [  1,  92],
#           [  2,  93],
#           [  2,  95],
#           [  4,  97],
#           [  4,  98],
#           [  6, 100],
#           [  6, 101],
#           [ 14, 109],
#           [ 15, 109],
#           [ 19, 113],
#           [ 20, 113],
#           [ 22, 115],
#           [ 23, 115],
#           [ 24, 116],
#           [ 25, 116],
#           [ 26, 117],
#           [ 27, 117],
#           [ 29, 119],
#           [ 30, 119],
#           [ 31, 120],
#           [ 32, 120],
#           [ 33, 121],
#           [ 34, 121],
#           [ 35, 122],
#           [ 36, 122],
#           [ 37, 123],
#           [ 38, 123],
#           [ 39, 124],
#           [ 40, 124],
#           [ 41, 125],
#           [ 42, 125],
#           [ 43, 126],
#           [ 45, 126],
#           [ 46, 127],
#           [ 48, 127],
#           [ 49, 128],
#           [ 51, 128],
#           [ 52, 129],
#           [ 55, 129],
#           [ 56, 130],
#           [ 67, 130],
#           [ 68, 129],
#           [ 71, 129],
#           [ 72, 128],
#           [ 74, 128],
#           [ 75, 127],
#           [ 76, 127],
#           [ 77, 126],
#           [ 79, 126],
#           [ 80, 125],
#           [ 81, 125],
#           [ 83, 123],
#           [ 84, 123],
#           [ 85, 122],
#           [ 86, 122],
#           [ 87, 121],
#           [ 88, 121],
#           [ 89, 120],
#           [ 90, 120],
#           [ 91, 119],
#           [ 92, 119],
#           [ 93, 118],
#           [ 94, 118],
#           [ 96, 116],
#           [ 97, 116],
#           [ 98, 115],
#           [ 99, 115],
#           [104, 110],
#           [105, 110],
#           [108, 107],
#           [109, 107],
#           [112, 104],
#           [113, 104],
#           [116, 101],
#           [116, 100],
#           [118,  98],
#           [118,  97],
#           [120,  95],
#           [120,  93],
#           [121,  92],
#           [121,  91],
#           [122,  90],
#           [122,  87],
#           [123,  86],
#           [123,  82],
#           [124,  81],
#           [124,  67],
#           [125,  66],
#           [125,  58],
#           [124,  57],
#           [124,  43],
#           [123,  42],
#           [123,  39],
#           [122,  38],
#           [122,  37],
#           [121,  36],
#           [121,  35],
#           [120,  34],
#           [120,  33],
#           [118,  31],
#           [118,  30],
#           [116,  28],
#           [116,  27],
#           [113,  24],
#           [112,  24],
#           [109,  21],
#           [108,  21],
#           [106,  19],
#           [105,  19],
#           [104,  18],
#           [103,  18],
#           [100,  15],
#           [ 99,  15],
#           [ 98,  14],
#           [ 97,  14],
#           [ 96,  13],
#           [ 95,  13],
#           [ 94,  12],
#           [ 93,  12],
#           [ 92,  11],
#           [ 91,  11],
#           [ 90,  10],
#           [ 89,  10],
#           [ 87,   8],
#           [ 86,   8],
#           [ 85,   7],
#           [ 84,   7],
#           [ 83,   6],
#           [ 82,   6],
#           [ 80,   4],
#           [ 79,   4],
#           [ 78,   3],
#           [ 77,   3],
#           [ 76,   2],
#           [ 75,   2],
#           [ 74,   1],
#           [ 72,   1],
#           [ 71,   0]], dtype=int32),
#   ),
#   ImagejRoi(
#       roitype=ROI_TYPE.FREEHAND,
#       options=ROI_OPTIONS.OVERLAY_BACKGROUNDS | ROI_OPTIONS.OVERLAY_LABELS,
#       name='a8657c12-acb4-11ee-be85-490a135c3209',
#       version=226,
#       top=117,
#       left=298,
#       bottom=247,
#       right=422,
#       n_coordinates=175,
#       integer_coordinates=numpy.array([
#           [ 58,   0],
#           [ 57,   1],
#           [ 54,   1],
#           [ 53,   2],
#           [ 51,   2],
#           [ 50,   3],
#           [ 48,   3],
#           [ 47,   4],
#           [ 45,   4],
#           [ 43,   6],
#           [ 42,   6],
#           [ 41,   7],
#           [ 40,   7],
#           [ 39,   8],
#           [ 38,   8],
#           [ 37,   9],
#           [ 36,   9],
#           [ 35,  10],
#           [ 34,  10],
#           [ 33,  11],
#           [ 32,  11],
#           [ 31,  12],
#           [ 30,  12],
#           [ 29,  13],
#           [ 28,  13],
#           [ 27,  14],
#           [ 26,  14],
#           [ 25,  15],
#           [ 24,  15],
#           [ 22,  17],
#           [ 21,  17],
#           [ 17,  21],
#           [ 16,  21],
#           [  9,  28],
#           [  9,  29],
#           [  6,  32],
#           [  6,  33],
#           [  4,  35],
#           [  4,  36],
#           [  3,  37],
#           [  3,  38],
#           [  2,  39],
#           [  2,  41],
#           [  1,  42],
#           [  1,  46],
#           [  0,  47],
#           [  0,  69],
#           [  1,  70],
#           [  1,  80],
#           [  0,  81],
#           [  0,  89],
#           [  1,  90],
#           [  1,  94],
#           [  2,  95],
#           [  2,  97],
#           [  3,  98],
#           [  3,  99],
#           [  5, 101],
#           [  5, 102],
#           [  6, 102],
#           [ 12, 108],
#           [ 13, 108],
#           [ 16, 111],
#           [ 17, 111],
#           [ 18, 112],
#           [ 19, 112],
#           [ 20, 113],
# ...
#           [ 24, 114],
#           [ 25, 114],
#           [ 26, 115],
#           [ 27, 115],
#           [ 29, 117],
#           [ 30, 117],
#           [ 31, 118],
#           [ 32, 118],
#           [ 33, 119],
#           [ 34, 119],
#           [ 36, 121],
#           [ 37, 121],
#           [ 38, 122],
#           [ 39, 122],
#           [ 40, 123],
#           [ 41, 123],
#           [ 42, 124],
#           [ 43, 124],
#           [ 44, 125],
#           [ 46, 125],
#           [ 47, 126],
#           [ 48, 126],
#           [ 49, 127],
#           [ 50, 127],
#           [ 51, 128],
#           [ 54, 128],
#           [ 55, 129],
#           [ 67, 129],
#           [ 68, 128],
#           [ 71, 128],
#           [ 72, 127],
#           [ 74, 127],
#           [ 75, 126],
#           [ 77, 126],
#           [ 78, 125],
#           [ 79, 125],
#           [ 81, 123],
#           [ 82, 123],
#           [ 83, 122],
#           [ 84, 122],
#           [ 85, 121],
#           [ 86, 121],
#           [ 87, 120],
#           [ 88, 120],
#           [ 90, 118],
#           [ 91, 118],
#           [ 92, 117],
#           [ 93, 117],
#           [ 95, 115],
#           [ 96, 115],
#           [ 99, 112],
#           [100, 112],
#           [102, 110],
#           [103, 110],
#           [105, 108],
#           [106, 108],
#           [109, 105],
#           [110, 105],
#           [111, 104],
#           [111, 103],
#           [114, 100],
#           [114,  99],
#           [117,  96],
#           [117,  95],
#           [119,  93],
#           [119,  92],
#           [120,  91],
#           [120,  90],
#           [121,  89],
#           [121,  86],
#           [122,  85],
#           [122,  76],
#           [123,  75],
#           [123,  62],
#           [122,  61],
#           [122,  43],
#           [121,  42],
#           [121,  39],
#           [120,  38],
#           [120,  36],
#           [119,  35],
#           [119,  34],
#           [118,  33],
#           [118,  32],
#           [117,  31],
#           [117,  30],
#           [116,  29],
#           [116,  28],
#           [113,  25],
#           [113,  24],
#           [110,  21],
#           [109,  21],
#           [107,  19],
#           [106,  19],
#           [105,  18],
#           [103,  18],
#           [102,  17],
#           [101,  17],
#           [ 99,  15],
#           [ 98,  15],
#           [ 97,  14],
#           [ 96,  14],
#           [ 94,  12],
#           [ 93,  12],
#           [ 92,  11],
#           [ 90,  11],
#           [ 89,  10],
#           [ 88,  10],
#           [ 87,   9],
#           [ 85,   9],
#           [ 84,   8],
#           [ 83,   8],
#           [ 82,   7],
#           [ 81,   7],
#           [ 80,   6],
#           [ 79,   6],
#           [ 78,   5],
#           [ 77,   5],
#           [ 76,   4],
#           [ 75,   4],
#           [ 74,   3],
#           [ 73,   3],
#           [ 72,   2],
#           [ 70,   2],
#           [ 69,   1],
#           [ 65,   1],
#           [ 64,   0]], dtype=int32),
#   ),
#   ImagejRoi(
#       roitype=ROI_TYPE.FREEHAND,
#       options=ROI_OPTIONS.OVERLAY_BACKGROUNDS | ROI_OPTIONS.OVERLAY_LABELS,
#       name='a8657bdf-acb4-11ee-be85-490a135c3209',
#       version=226,
#       top=853,
#       left=842,
#       bottom=984,
#       right=967,
#       n_coordinates=174,
#       integer_coordinates=numpy.array([
#           [ 61,   0],
#           [ 60,   1],
#           [ 56,   1],
#           [ 55,   2],
#           [ 51,   2],
#           [ 50,   3],
#           [ 47,   3],
#           [ 46,   4],
#           [ 45,   4],
#           [ 44,   5],
#           [ 43,   5],
#           [ 42,   6],
#           [ 41,   6],
#           [ 39,   8],
#           [ 38,   8],
#           [ 37,   9],
#           [ 36,   9],
#           [ 34,  11],
#           [ 33,  11],
#           [ 32,  12],
#           [ 31,  12],
#           [ 30,  13],
#           [ 29,  13],
#           [ 28,  14],
#           [ 27,  14],
#           [ 26,  15],
#           [ 25,  15],
#           [ 24,  16],
#           [ 23,  16],
#           [ 21,  18],
#           [ 20,  18],
#           [ 18,  20],
#           [ 17,  20],
#           [ 13,  24],
#           [ 12,  24],
#           [  9,  27],
#           [  9,  28],
#           [  6,  31],
#           [  6,  32],
#           [  5,  33],
#           [  5,  34],
#           [  4,  35],
#           [  4,  38],
#           [  3,  39],
#           [  3,  43],
#           [  2,  44],
#           [  2,  49],
#           [  1,  50],
#           [  1,  64],
#           [  0,  65],
#           [  0,  73],
#           [  1,  74],
#           [  1,  88],
#           [  2,  89],
#           [  2,  92],
#           [  3,  93],
#           [  3,  94],
#           [  4,  95],
#           [  4,  96],
#           [  6,  98],
#           [  6,  99],
#           [ 14, 107],
#           [ 15, 107],
#           [ 27, 119],
#           [ 28, 119],
#           [ 30, 121],
#           [ 31, 121],
#           [ 34, 124],
#           [ 35, 124],
#           [ 36, 125],
#           [ 38, 125],
#           [ 39, 126],
#           [ 40, 126],
#           [ 41, 127],
#           [ 43, 127],
#           [ 44, 128],
#           [ 46, 128],
#           [ 47, 129],
#           [ 52, 129],
#           [ 53, 130],
#           [ 68, 130],
#           [ 69, 129],
#           [ 73, 129],
#           [ 74, 128],
#           [ 75, 128],
#           [ 76, 127],
#           [ 78, 127],
#           [ 79, 126],
#           [ 80, 126],
#           [ 81, 125],
#           [ 82, 125],
#           [ 83, 124],
#           [ 84, 124],
#           [ 85, 123],
#           [ 86, 123],
#           [ 87, 122],
#           [ 88, 122],
#           [ 90, 120],
#           [ 91, 120],
#           [ 92, 119],
#           [ 93, 119],
#           [ 95, 117],
#           [ 96, 117],
#           [ 97, 116],
#           [ 98, 116],
#           [ 99, 115],
#           [100, 115],
#           [102, 113],
#           [103, 113],
#           [104, 112],
#           [105, 112],
#           [106, 111],
#           [107, 111],
#           [110, 108],
#           [111, 108],
#           [117, 102],
#           [117, 101],
#           [119,  99],
#           [119,  98],
#           [120,  97],
#           [120,  95],
#           [121,  94],
#           [121,  93],
#           [122,  92],
#           [122,  90],
#           [123,  89],
#           [123,  80],
#           [124,  79],
#           [124,  46],
#           [123,  45],
#           [123,  42],
#           [122,  41],
#           [122,  38],
#           [121,  37],
#           [121,  35],
#           [120,  34],
#           [120,  33],
#           [115,  28],
#           [115,  27],
#           [113,  25],
#           [112,  25],
#           [109,  22],
#           [108,  22],
#           [105,  19],
#           [104,  19],
#           [100,  15],
#           [ 99,  15],
#           [ 98,  14],
#           [ 97,  14],
#           [ 96,  13],
#           [ 95,  13],
#           [ 94,  12],
#           [ 93,  12],
#           [ 92,  11],
#           [ 91,  11],
#           [ 90,  10],
#           [ 89,  10],
#           [ 88,   9],
#           [ 87,   9],
#           [ 85,   7],
#           [ 84,   7],
#           [ 83,   6],
#           [ 82,   6],
#           [ 81,   5],
#           [ 79,   5],
#           [ 78,   4],
#           [ 77,   4],
#           [ 76,   3],
#           [ 74,   3],
#           [ 73,   2],
#           [ 71,   2],
#           [ 70,   1],
#           [ 65,   1],
#           [ 64,   0]], dtype=int32),
#   ),
#   ImagejRoi(
#       roitype=ROI_TYPE.FREEHAND,
#       options=ROI_OPTIONS.OVERLAY_BACKGROUNDS | ROI_OPTIONS.OVERLAY_LABELS,
#       name='a8657bfc-acb4-11ee-be85-490a135c3209',
#       version=226,
#       top=857,
#       left=984,
#       bottom=987,
#       right=1107,
#       n_coordinates=183,
#       integer_coordinates=numpy.array([
#           [ 57,   0],
#           [ 56,   1],
#           [ 51,   1],
#           [ 50,   2],
#           [ 49,   2],
#           [ 48,   3],
#           [ 47,   3],
#           [ 46,   4],
#           [ 45,   4],
#           [ 44,   5],
#           [ 43,   5],
#           [ 42,   6],
#           [ 41,   6],
#           [ 39,   8],
#           [ 38,   8],
#           [ 36,  10],
#           [ 35,  10],
#           [ 34,  11],
#           [ 33,  11],
#           [ 32,  12],
#           [ 31,  12],
#           [ 26,  17],
#           [ 25,  17],
#           [ 23,  19],
#           [ 22,  19],
#           [ 20,  21],
#           [ 19,  21],
#           [ 18,  22],
#           [ 17,  22],
#           [ 14,  25],
#           [ 13,  25],
#           [ 11,  27],
#           [ 11,  28],
#           [  8,  31],
#           [  8,  32],
#           [  7,  33],
#           [  7,  34],
#           [  6,  35],
#           [  6,  37],
#           [  5,  38],
#           [  5,  40],
#           [  4,  41],
#           [  4,  43],
#           [  3,  44],
#           [  3,  48],
#           [  2,  49],
#           [  2,  60],
#           [  1,  61],
#           [  1,  74],
#           [  0,  75],
#           [  0,  90],
#           [  1,  91],
#           [  1,  94],
#           [  2,  95],
#           [  2,  96],
#           [  3,  97],
#           [  3,  98],
#           [  8, 103],
#           [  9, 103],
#           [ 13, 107],
#           [ 14, 107],
#           [ 18, 111],
#           [ 19, 111],
#           [ 20, 112],
#           [ 21, 112],
#           [ 23, 114],
#           [ 24, 114],
#           [ 25, 115],
#           [ 26, 115],
#           [ 27, 116],
#           [ 28, 116],
#           [ 29, 117],
#           [ 30, 117],
#           [ 31, 118],
#           [ 32, 118],
#           [ 34, 120],
#           [ 35, 120],
#           [ 37, 122],
#           [ 38, 122],
#           [ 39, 123],
#           [ 40, 123],
#           [ 42, 125],
#           [ 43, 125],
#           [ 44, 126],
#           [ 45, 126],
#           [ 46, 127],
#           [ 49, 127],
#           [ 50, 128],
#           [ 53, 128],
#           [ 54, 129],
#           [ 66, 129],
#           [ 67, 128],
#           [ 70, 128],
#           [ 71, 127],
#           [ 72, 127],
#           [ 73, 126],
#           [ 74, 126],
#           [ 75, 125],
#           [ 76, 125],
#           [ 77, 124],
#           [ 78, 124],
#           [ 79, 123],
#           [ 80, 123],
#           [ 81, 122],
#           [ 82, 122],
#           [ 83, 121],
#           [ 84, 121],
#           [ 85, 120],
#           [ 86, 120],
#           [ 87, 119],
#           [ 88, 119],
#           [ 89, 118],
#           [ 90, 118],
#           [ 91, 117],
#           [ 93, 117],
#           [ 95, 115],
#           [ 96, 115],
#           [ 98, 113],
#           [ 99, 113],
#           [100, 112],
#           [101, 112],
#           [103, 110],
#           [104, 110],
#           [107, 107],
#           [108, 107],
#           [111, 104],
#           [112, 104],
#           [112, 103],
#           [114, 101],
#           [114, 100],
#           [116,  98],
#           [116,  97],
#           [118,  95],
#           [118,  94],
#           [119,  93],
#           [119,  91],
#           [120,  90],
#           [120,  87],
#           [121,  86],
#           [121,  81],
#           [122,  80],
#           [122,  53],
#           [121,  52],
#           [121,  43],
#           [120,  42],
#           [120,  39],
#           [119,  38],
#           [119,  36],
#           [118,  35],
#           [118,  33],
#           [116,  31],
#           [116,  30],
#           [111,  25],
#           [110,  25],
#           [108,  23],
#           [107,  23],
#           [104,  20],
#           [103,  20],
#           [100,  17],
#           [ 99,  17],
#           [ 96,  14],
#           [ 95,  14],
#           [ 93,  12],
#           [ 92,  12],
#           [ 91,  11],
#           [ 90,  11],
#           [ 89,  10],
#           [ 88,  10],
#           [ 85,   7],
#           [ 84,   7],
#           [ 83,   6],
#           [ 82,   6],
#           [ 81,   5],
#           [ 80,   5],
#           [ 79,   4],
#           [ 77,   4],
#           [ 76,   3],
#           [ 75,   3],
#           [ 74,   2],
#           [ 73,   2],
#           [ 72,   1],
#           [ 68,   1],
#           [ 67,   0]], dtype=int32),
#   ),
#   ImagejRoi(
#       roitype=ROI_TYPE.FREEHAND,
#       options=ROI_OPTIONS.OVERLAY_BACKGROUNDS | ROI_OPTIONS.OVERLAY_LABELS,
#       name='a8657c21-acb4-11ee-be85-490a135c3209',
#       version=226,
#       top=860,
#       left=1126,
#       bottom=991,
#       right=1247,
#       n_coordinates=195,
#       integer_coordinates=numpy.array([
#           [ 63,   0],
#           [ 62,   1],
#           [ 57,   1],
#           [ 56,   2],
#           [ 54,   2],
#           [ 52,   4],
#           [ 52,   6],
#           [ 49,   9],
#           [ 45,   9],
#           [ 44,  10],
#           [ 43,  10],
#           [ 42,  11],
#           [ 41,  11],
#           [ 40,  12],
#           [ 38,  12],
#           [ 37,  13],
#           [ 36,  13],
#           [ 35,  14],
#           [ 34,  14],
#           [ 33,  15],
#           [ 32,  15],
#           [ 31,  16],
#           [ 30,  16],
#           [ 29,  17],
#           [ 28,  17],
#           [ 27,  18],
#           [ 26,  18],
#           [ 25,  19],
#           [ 24,  19],
#           [ 23,  20],
#           [ 22,  20],
#           [ 18,  24],
#           [ 17,  24],
#           [ 15,  26],
#           [ 14,  26],
#           [ 10,  30],
#           [ 10,  31],
#           [  9,  32],
#           [  9,  34],
#           [  8,  35],
#           [  8,  36],
#           [  6,  38],
#           [  6,  39],
#           [  5,  40],
#           [  5,  44],
#           [  4,  45],
#           [  4,  47],
#           [  3,  48],
#           [  3,  51],
#           [  2,  52],
#           [  2,  59],
#           [  1,  60],
#           [  1,  79],
#           [  0,  80],
#           [  0,  87],
#           [  1,  88],
#           [  1,  92],
#           [  2,  93],
#           [  2,  94],
#           [  3,  95],
#           [  3,  96],
#           [  4,  97],
#           [  4,  98],
#           [  5,  99],
#           [  5, 100],
#           [  7, 102],
#           [  7, 103],
#           [ 12, 108],
#           [ 13, 108],
#           [ 18, 113],
#           [ 19, 113],
#           [ 20, 114],
#           [ 21, 114],
#           [ 24, 117],
#           [ 25, 117],
#           [ 27, 119],
#           [ 28, 119],
#           [ 29, 120],
#           [ 30, 120],
#           [ 33, 123],
#           [ 34, 123],
#           [ 35, 124],
#           [ 36, 124],
#           [ 37, 125],
#           [ 39, 125],
#           [ 40, 126],
#           [ 41, 126],
#           [ 42, 127],
#           [ 43, 127],
#           [ 44, 128],
#           [ 46, 128],
#           [ 47, 129],
#           [ 51, 129],
#           [ 52, 130],
#           [ 56, 130],
#           [ 57, 129],
#           [ 64, 129],
#           [ 65, 128],
#           [ 69, 128],
#           [ 70, 127],
#           [ 72, 127],
#           [ 73, 126],
#           [ 75, 126],
#           [ 76, 125],
#           [ 77, 125],
#           [ 78, 124],
#           [ 79, 124],
#           [ 80, 123],
#           [ 81, 123],
#           [ 82, 122],
#           [ 83, 122],
#           [ 84, 121],
#           [ 85, 121],
#           [ 86, 120],
#           [ 87, 120],
#           [ 88, 119],
#           [ 89, 119],
#           [ 91, 117],
#           [ 92, 117],
#           [ 93, 116],
#           [ 94, 116],
#           [ 95, 115],
#           [ 96, 115],
#           [ 98, 113],
#           [ 99, 113],
#           [100, 112],
#           [101, 112],
#           [103, 110],
#           [104, 110],
#           [105, 109],
#           [106, 109],
#           [110, 105],
#           [111, 105],
#           [112, 104],
#           [112, 103],
#           [114, 101],
#           [114, 100],
#           [115,  99],
#           [115,  98],
#           [116,  97],
#           [116,  96],
#           [117,  95],
#           [117,  94],
#           [118,  93],
#           [118,  92],
#           [119,  91],
#           [119,  87],
#           [120,  86],
#           [120,  45],
#           [119,  44],
#           [119,  39],
#           [118,  38],
#           [118,  36],
#           [117,  35],
#           [117,  33],
#           [116,  32],
#           [116,  30],
#           [114,  28],
#           [114,  27],
#           [111,  24],
#           [111,  23],
#           [110,  22],
#           [109,  22],
#           [107,  20],
#           [106,  20],
#           [105,  19],
#           [104,  19],
#           [103,  18],
#           [102,  18],
#           [101,  17],
#           [100,  17],
#           [ 99,  16],
#           [ 97,  16],
#           [ 96,  15],
#           [ 94,  15],
#           [ 93,  14],
#           [ 92,  14],
#           [ 91,  13],
#           [ 90,  13],
#           [ 89,  12],
#           [ 86,  12],
#           [ 85,  11],
#           [ 82,  11],
#           [ 81,  10],
#           [ 79,  10],
#           [ 78,   9],
#           [ 77,   9],
#           [ 75,   7],
#           [ 75,   6],
#           [ 73,   4],
#           [ 73,   3],
#           [ 72,   3],
#           [ 70,   1],
#           [ 66,   1],
#           [ 65,   0]], dtype=int32),
#   )]}
